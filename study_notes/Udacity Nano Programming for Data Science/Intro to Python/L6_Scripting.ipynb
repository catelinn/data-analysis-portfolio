# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Running-and-Editing-Python-Scripts" data-toc-modified-id="Running-and-Editing-Python-Scripts-1">Running and Editing Python Scripts</a></span><ul class="toc-item"><li><span><a href="#Scripts-of-this-Course" data-toc-modified-id="Scripts-of-this-Course-1.1">Scripts of this Course</a></span></li></ul></li><li><span><a href="#User-Input" data-toc-modified-id="User-Input-2">User Input</a></span></li><li><span><a href="#Handling-Exceptions" data-toc-modified-id="Handling-Exceptions-3">Handling Exceptions</a></span><ul class="toc-item"><li><span><a href="#Try-Statement" data-toc-modified-id="Try-Statement-3.1"><code>Try</code> Statement</a></span></li><li><span><a href="#Specifying-Exceptions" data-toc-modified-id="Specifying-Exceptions-3.2">Specifying Exceptions</a></span></li><li><span><a href="#Accessing-System-Error-Messages" data-toc-modified-id="Accessing-System-Error-Messages-3.3">Accessing System Error Messages</a></span></li></ul></li><li><span><a href="#Reading-and-Writing-Files" data-toc-modified-id="Reading-and-Writing-Files-4">Reading and Writing Files</a></span><ul class="toc-item"><li><span><a href="#Reading-a-file---open,-.read,-.close" data-toc-modified-id="Reading-a-file---open,-.read,-.close-4.1">Reading a file - <code>open</code>, <code>.read</code>, <code>.close</code></a></span></li><li><span><a href="#Writing-to-a-file" data-toc-modified-id="Writing-to-a-file-4.2">Writing to a file</a></span></li><li><span><a href="#Adding-content-to-a-file" data-toc-modified-id="Adding-content-to-a-file-4.3">Adding content to a file</a></span></li><li><span><a href="#with-keyword" data-toc-modified-id="with-keyword-4.4"><code>with</code> keyword</a></span></li><li><span><a href="#Ways-of-Reading-File" data-toc-modified-id="Ways-of-Reading-File-4.5">Ways of Reading File</a></span><ul class="toc-item"><li><span><a href="#.read-with-an-integer-argument" data-toc-modified-id=".read-with-an-integer-argument-4.5.1"><code>.read</code> with an integer argument</a></span></li><li><span><a href="#Reading-line-by-line" data-toc-modified-id="Reading-line-by-line-4.5.2">Reading line by line</a></span></li></ul></li></ul></li><li><span><a href="#Importing-Modules" data-toc-modified-id="Importing-Modules-5">Importing Modules</a></span><ul class="toc-item"><li><span><a href="#Local-Modules-(scripts)" data-toc-modified-id="Local-Modules-(scripts)-5.1">Local Modules (scripts)</a></span><ul class="toc-item"><li><span><a href="#import" data-toc-modified-id="import-5.1.1"><code>import</code></a></span></li><li><span><a href="#Using-a-main-block" data-toc-modified-id="Using-a-main-block-5.1.2">Using a <code>main</code> block</a></span></li><li><span><a href="#The-built-in-__name__-variable" data-toc-modified-id="The-built-in-__name__-variable-5.1.3">The built-in <code>__name__</code> variable</a></span></li></ul></li><li><span><a href="#Standard-Modules" data-toc-modified-id="Standard-Modules-5.2">Standard Modules</a></span><ul class="toc-item"><li><span><a href="#Importing-Techniques" data-toc-modified-id="Importing-Techniques-5.2.1">Importing Techniques</a></span></li><li><span><a href="#Resources" data-toc-modified-id="Resources-5.2.2">Resources</a></span></li><li><span><a href="#Recommended-Modules" data-toc-modified-id="Recommended-Modules-5.2.3">Recommended Modules</a></span></li><li><span><a href="#Quiz---Password-Generator" data-toc-modified-id="Quiz---Password-Generator-5.2.4">Quiz - Password Generator</a></span></li></ul></li><li><span><a href="#Third-party-Modules" data-toc-modified-id="Third-party-Modules-5.3">Third-party Modules</a></span><ul class="toc-item"><li><span><a href="#pip-install-and-requirements.txt" data-toc-modified-id="pip-install-and-requirements.txt-5.3.1"><code>pip install</code> and <code>requirements.txt</code></a></span></li><li><span><a href="#Resources" data-toc-modified-id="Resources-5.3.2">Resources</a></span></li></ul></li></ul></li><li><span><a href="#Using-Interactive-Interpreter" data-toc-modified-id="Using-Interactive-Interpreter-6">Using Interactive Interpreter</a></span><ul class="toc-item"><li><span><a href="#python" data-toc-modified-id="python-6.1"><code>python</code></a></span></li><li><span><a href="#ipython" data-toc-modified-id="ipython-6.2"><code>ipython</code></a></span></li></ul></li><li><span><a href="#Final-Practice" data-toc-modified-id="Final-Practice-7">Final Practice</a></span></li></ul></div>

# %% [markdown]
# # Running and Editing Python Scripts
# - Use code editor to save scripts as `script.py`
# - Run script in shell using `python script.py`
# - Make sure the script can print output or return the result by calling a function defined
#
# ## Scripts of this Course
#
# All scripts in this course are saved under `scripts/`.

# %% [markdown]
# # User Input
#
# Refer to `raw_input_practice.py`

# %% [markdown]
# # Handling Exceptions
#
# `Exception` is just the **base class** for all built-in exceptions. You can learn more about [Python's exceptions](https://docs.python.org/3/library/exceptions.html#bltin-exceptions) here.
#
# ## `Try` Statement
#
# **We can use `try` statements to handle exceptions**. There are **four clauses** you can use:
#
# - `try`: This is the only mandatory clause in a `try` statement. The code in this block is the first thing that Python runs in a `try` statement.
#
#
# - `except`: If Python runs into an exception while running the `try` block, it will jump to the `except` block that handles that exception.
#
#
# - `else`: If Python runs into no exceptions while running the `try` block, it will run the code in this block after running the `try` block.
#
#
# - `finally`: Before Python leaves this `try` statement, it will run the code in this `finally` block **under any conditions**, even if it's ending the program. E.g., if Python ran into an error while running code in the `except` or `else` block, this `finally` block will still be executed before stopping the program.
#
# [Why do we need `finally` block](https://stackoverflow.com/questions/11551996/why-do-we-need-the-finally-clause-in-python)
#
# ```Python
# # Use `while` loop to ask user for input until
# # it passes the `try` block
# while True:
#     try:
#         x = int(input("Enter a number: "))
#         break
#     except:
#         print("That\'s not a valid number!")
#     # this block will run everytime no matter what
#     finally:
#         print("\nAttempted Input\n")
#
# ```
#
# ## Specifying Exceptions
#
# We can actually specify which error we want to handle in an `except` block:
#
# ```Python
# # to address the `ValueError`
# try:
#     # some code
# except ValueError:
#     # some code
#
#
# # to address more than one type of exception
# try:
#     # some code
# except (ValueError, KeyboardInterrupt):
#     # some code
#
#
# # to execute different blocks of code depending on the exception
# try:
#     # some code
# except ValueError:
#     # some code
# except KeyboardInterrupt:
#     # some code
# ```

# %% [markdown]
# ## Accessing System Error Messages
#
# When you handle an exception, you can still access its error message:
#
# ```Python
# try:
#     # some code
# except ZeroDivisionError as e:
#    # some code
#    print("ZeroDivisionError occurred: {}".format(e))
# ```
#
# This will print:
# ```Python
# ZeroDivisionError occurred: integer division or modulo by zero
# ```
#
# If you don't have a specific error to handle, you can still access the message:
# ```Python
# try:
#     # some code
# except Exception as e:
#    # some code
#    print("Exception occurred: {}".format(e))
# ```

# %% [markdown]
# # Reading and Writing Files
#
# ## Reading a file - `open`, `.read`, `.close`
# ```Python
# # `open` returns a file object, which is a Python object through which Python interacts with the file itself.
# # The default `open` mode is `r`, which means `read`
# f = open('my_path/my_file.txt', 'r')
#
# # The `read` method accesses the contents from `f`.
# # It takes the text in a file and puts it into a string.
# file_data = f.read()
#
# # Always `close` file to free up the system resources taken up by the file
# f.close()
# ```
#
# ## Writing to a file
#
# If the file does not exist, Python will create it for you. If you open an existing file in writing mode, any content that it had previously will be **DELETED**!
# ```Python
# # Open the file in writing ('w') mode.
# f = open('my_path/my_file.txt', 'w')
# f.write("Hello there!")
# f.close()
# ```
#
# ## Adding content to a file
#
# If you're interested in adding to an existing file, without deleting its content, you should use the append (`a`) mode instead of write.
#
# ```Python
# f = open('my_path/my_file.txt', 'a')
# f.write("\nNew content here!")
# f.close()
# ```
#
# ## `with` keyword
#
# ```Python
# # You can only access the file object, `f`, within this indented block.
# # Now, we don’t have to call `f.close()`!
# with open('my_path/my_file.txt', 'r') as f:
#     file_data = f.read()
# ```

# %% [markdown]
# ## Ways of Reading File
#
# ### `.read` with an integer argument
#
# If you pass `.read` method an integer argument, it will read up to that number of characters, output all of them, and keep the 'window' at that position ready to read on
# > `.read` works like an iterator
#
# Say, this is the text in `camelot.txt` file:
# ```
# We're the knights of the round table
# We dance whenever we're able
# ```
# Here's a script that reads in the file a little at a time:
# ```Python
# with open("camelot.txt") as song:
#     print(song.read(2))
#     print(song.read(8))
#     print(song.read())
# ```
#
# Outputs:
# ```
# We
# 're the
# knights of the round table
# We dance whenever we're able
#
# ```
#
#
# ### Reading line by line
#
# `\n`s in blocks of text are newline characters. The newline character marks the end of a line. Python knows that these are special characters so you can read line by line of a file:
#
# ```Python
# # read single line
# with open("camelot.txt") as f:
#     first_line = f.readline()
#     second_line = f.readline()
#
# # read all lines - method 1
# with open("camelot.txt") as f:
#     lines = f.readlines()
#
# # read all lines - method 2
# with open("camelot.txt") as f:
#     lines = list(f)
#
# # read all lines - method 3
# # loop over the lines (memory efficient, fast)
# with open("camelot.txt") as f:
#     for line in f:
#         print(line)
#
# # create list of lines with `\n` character removed
# lines = []
# with open("camelot.txt") as f:
#     for line in f:
#         lines.append(line.strip())
#
# print(lines)
# ```
#
# Output:
#
# ```
# ["We're the knights of the round table", "We dance whenever we're able"]
# ```

# %% [markdown]
# # Importing Modules
#
#
# ## Local Modules (scripts)
#
#
# ### `import`
# ```Python
# # import and access imported functions
# import useful_functions
# useful_functions.mean([1,2,3,4])
#
# # access imported variables
# print(useful_functions.num)
#
# # Use alias to access imported functions
# import useful_functions as uf
# uf.mean([1,2,3,4])
# ```
#
# [Python Doc - Local Module](https://docs.python.org/2/tutorial/modules.html#modules)
#
# ### Using a `main` block
#
# Scripts saved under `scripts/`:
# - `demo.py`
# - `useful_functions.py`
#
# >If the script (module) to be imported has executable statements, like the `main()` block in `useful_functions.py`, to avoid `main()` run when the script being imported, the following line is added:
# ```Python
# if __name__ == "__main__"
# ```
#
# [Python Doc - Executing modules as scripts](https://docs.python.org/2/tutorial/modules.html#executing-modules-as-scripts)
#
# ### The built-in `__name__` variable
# - When we run a script, Python recognizes this script (module) as the main program, and sets its `__name__` variable the string `"__main__"`.
# ```Python
# # this will print `__main__` for the current script run
# print(__name__)
# ```
#
# - For any modules that are imported in a script, this built-in `__name__` variable is just set to the name of that module.
# ```Python
# # this will print the name of `uf` module, which is the original script name - "useful_functions"
# print(uf.__name__)
# ```

# %% [markdown]
# ## Standard Modules
#
# The Python's built-in modules, such as `math`, `os`.
#
# ### Importing Techniques
#
# ```Python
# #======= To import an individual function or object =====
# # To import an individual function or class from a module:
# from module_name import object_name
#
# # To import multiple individual objects from a module
# from module_name import first_object, second_object
#
# # To import an object from a module and rename it
# from module_name import object_name as new_object_name
#
# #======= To import all objects from a module =====
# # DO NOT DO THIS!
# from module_name import *
# # Do this!
# import module_name
#
#
# #======= To import a sub-module from a package ==========
# # A pacakge is simply a module that contains sub-modules
# # package and sub-module structure is used to manage the code better
# import package_name.submodule_name
#
# # e.g. to import os.path, a submodule of os:
# import os.path
#
# ```
#
# |Import Statement|Calling the function|
# |:---|:---|
# |`import random`|`random.randint(0,10)`|
# |`from random import randint`|`randint(0,10)`|
# |`import random as rd`|`rd.randint(0,10)`|
# |`from random import randint as print`|`rint(0,10)`|
# |`from random import *`|Don't use this import statement!
#
#
# ### Resources
#
# [Python 3 Standard Modules Complete List](https://docs.python.org/3/library/)
#
# [Python Module of the Week 3](https://pymotw.com/3/) - PyMOTW-3 is a series of articles written by Doug Hellmann. to demonstrate how to use the modules of the Python 3 standard library.
#
#
# ### Recommended Modules
#
# The [Python Standard Library](https://docs.python.org/3.7/library/index.html) has a lot of modules!
#
# - `csv`: very convenient for reading and writing csv files
# - `collections`: useful extensions of the usual data types including OrderedDict, defaultdict and namedtuple
# - `random`: generates pseudo-random numbers, shuffles sequences randomly and chooses random items
# - `string`: more functions on strings. This module also contains useful collections of letters like string.digits (a string containing all characters which are valid digits).
# - `re`: pattern-matching in strings via regular expressions
# - `math`: some standard mathematical functions
# - `os`: interacting with operating systems
# - `os.path`: submodule of os for manipulating path names
# - `sys`: work directly with the Python interpreter
# - `json`: good for reading and writing json files (good for web work)
#
#
#
# ### Quiz - Password Generator
#
# Write a function called `generate_password` that selects three random words from the list of words `word_list` and concatenates them into a single string.
#
# **Search [Python standard library of the right version of Python](https://docs.python.org/3.7/library/index.html) for the appropriate module and function to use**

# %%
# Use an import statement at the top
import random
word_file = "scripts/words.txt"
word_list = []

#fill up the word_list
with open(word_file,'r') as words:
    for line in words:
        # remove white space and make everything lowercase
        word = line.strip().lower()
        # don't include words that are too long or too short
        if 3 < len(word) < 8:
            word_list.append(word)

# Add your function generate_password here
# It should return a string consisting of three random words 
# concatenated together without spaces
def generate_password():
    random_words = random.sample(word_list,k=3)
    return ''.join(random_words)


# test your function
print(generate_password())
# Out:
# readingtiredthought

# %% [markdown]
# ## Third-party Modules
#
# There are tens of thousands of **third-party libraries** written by independent developers!
#
# ### `pip install` and `requirements.txt`
#
# You can install them using `pip`, a package manager that is included with Python 3
#
# ```Python
# # To install a package using pip
# pip install package_name
#
# # To install all of a project's dependencies at once
# pip install -r requirements.txt
# ```
#
# To make it easier to share these programs, programmers often list a project's dependencies in a file called `requirements.txt`:
# ```Shell
# # Include the name of a package and its version number.
# beautifulsoup4==4.5.1
# bs4==0.0.1
# pytz==2016.7
# requests==2.11.1
# ```
#
#
# ### Resources
#
# - `IPython` - A better interactive Python interpreter
# - `requests` - Provides easy to use methods to make web requests. Useful for accessing web APIs.
# - `Flask` - a lightweight framework for making web applications and APIs.
# - `Django` - A more featureful framework for making web applications. Django is particularly good for designing complex, content heavy, web applications.
# - `Beautiful Soup` - Used to parse HTML and extract information from it. Great for web scraping.
# - `pytest` - extends Python's builtin assertions and unittest module.
# - `PyYAML` - For reading and writing YAML files.
# - `NumPy` - The fundamental package for scientific computing with Python. It contains among other things a powerful N-dimensional array object and useful linear algebra capabilities.
# - `pandas` - A library containing high-performance, data structures and data analysis tools. In particular, pandas provides dataframes!
# - `matplotlib` - a 2D plotting library which produces publication quality figures in a variety of hardcopy formats and interactive environments.
# - `ggplot` - Another 2D plotting library, based on R's ggplot2 library.
# - `Pillow` - The Python Imaging Library adds image processing capabilities to your Python interpreter.
# - `pyglet` - A cross-platform application framework intended for game development.
# - `Pygame` - A set of Python modules designed for writing games.
# - `pytz` - World Timezone Definitions for Python

# %% [markdown]
# # Using Interactive Interpreter
#
# ## `python`
#
# - Run `python` in shell to open Python interactive interpreter.
# - Press `Ctrl-D` or type `exit()` to quit
#
#
#
# ## `ipython`
#
# - Run `ipython` in shell to open IPython interactive interpreter.
# - Press `Ctrl-D` or type `exit()` to quit
#
#
# > `ipython` is a better alternative to `python` interactive interpreter with the following great features:
# - tab completion
# - `?` for details about an object
# - `!` to execute system shell commands
# - syntax highligting!
#
# `ipython` is the underlying framework for `jupyter notebook`.
#
# [ipython tutorials](https://ipython.org/ipython-doc/3/interactive/tutorial.html)

# %% [markdown]
# # Final Practice
#
# Refer to `match_flower_name.py` and `flowers.txt`.
