# %% [markdown]
# ### Fuzzy string matching in Python
#
# [fuzzywuzzy](https://marcobonzanini.com/2015/02/25/fuzzy-string-matching-in-python/)

# %%
import fuzzywuzzy
from fuzzywuzzy import process

# %% [markdown]
# ### vLookup in Python
#
# [how to do a vlookup in Python](https://michaeljsanders.com/2017/04/17/python-vlookup.html)
#
# - `.map()` with a dictionary
# - `.merge()` with a left join

# %%
import numpy as np
import pandas as pd
import os
pd.set_option('display.max_rows', 6)

# %%
script_dir = '\\Users\\Catel\\Google Drive\\US and Canada Cases\\trademark not in report yet\\Scripts'

# %%
output_dir = '\\Users\\Catel\\Google Drive\\US and Canada Cases'

# %%
# clients on file
clients = pd.read_excel(output_dir + '/' + 'clients.xlsx')
clients
# Out:
#                             委托人 委托人性质 委托人其他使用名
# 0                          3COR   合作所      NaN
# 1           ADAMS GRUMBLES, LLP   合作所      NaN
# 2        ALPHABET BRAND COMPANY    企业      NaN
# ..                          ...   ...      ...
# 220    HAROLD W. ASHENMIL, Q.C.   合作所      NaN
# 221         LUXURY & LAYLA INC.    企业      NaN
# 222  THOMAS & BETTS CORPORATION    企业      NaN
#
# [223 rows x 3 columns]

# %%
# cases on file (extract those need to look up for 委托人性质)
cases = pd.read_excel(output_dir + '/' + 'final20190103115338.xlsx')
cases = cases.set_index(np.arange(len(cases)))

# %%
cases_for_lookup = cases.loc[cases.委托人性质.isna()]
cases_for_lookup
# Out:
#                                  委托人 委托人国别             本所案号   案件类型  \
# 7072          BCF S.E.N.C.R.L. / LLP   加拿大  UIT1806856.CA.1  变更代理人
# 7073          BCF S.E.N.C.R.L. / LLP   加拿大  UIT1806857.CA.1  变更代理人
# 7074          BCF S.E.N.C.R.L. / LLP   加拿大  UIT1806858.CA.1  变更代理人
# ...                              ...   ...              ...    ...
# 7513  GREENBERG TRAURIG, LLP(BOSTON)    美国  UIT1807678.AS.1     转让
# 7514  GREENBERG TRAURIG, LLP(BOSTON)    美国  UIT1807679.AS.1     转让
# 7515  GREENBERG TRAURIG, LLP(BOSTON)    美国  UIT1807680.AS.1     转让
#
#                   申请人 申请人国别                        商标名称  类别       商标号  \
# 7072    芭拉多斯保安系统巴哈马公司   巴哈马                PARADOX FIRE   9   8510953
# 7073  芭拉多斯保安系统巴哈马有限公司   巴哈马            PARADOX IMPERIAL   9   6962291
# 7074  芭拉多斯保安系统巴哈马有限公司   巴哈马                MAMA；PARADOX   9   6424404
# ...               ...   ...                         ...  ..       ...
# 7513          三伟达保健公司    美国  TRIPLE SENSE TECHNOLOGY及图形  10  34776257
# 7514          三伟达保健公司    美国  TRIPLE SENSE TECHNOLOGY及图形  35  34794844
# 7515          三伟达保健公司    美国  TRIPLE SENSE TECHNOLOGY及图形  42  34793658
#
#              立案日 委托人性质  Year  Month
# 7072  2018-11-26   NaN  2018     11
# 7073  2018-11-26   NaN  2018     11
# 7074  2018-11-26   NaN  2018     11
# ...          ...   ...   ...    ...
# 7513  2018-12-29   NaN  2018     12
# 7514  2018-12-29   NaN  2018     12
# 7515  2018-12-29   NaN  2018     12
#
# [444 rows x 13 columns]

# %% [markdown]
# #### Get best match from fuzzy look up result of one of the cases

# %%
testResult = process.extractOne('HERSCHEL SUPPLY COMPANY LTD.', clients['委托人'])
testResult
# Out:
# ('HERSCHEL SUPPLY COMPANY LTD.', 100, 72)

# %%
testResult = process.extractOne(cases_for_lookup.iloc[0]['委托人'], clients['委托人'])
testResult
# Out:
# ('BCF S.E.N.C.R.L. / LLP', 100, 12)

# %% [markdown]
# #### fuzzy lookup and best match on all cases

# %%
bestMatches = cases_for_lookup['委托人'].apply(lambda x: process.extractOne(x, clients['委托人']) if process.extractOne(x, clients['委托人'])[1] > 90 else process.extractOne(x, clients['委托人其他使用名']) )

# %%
bestMatches
# Out:
# 7072            (BCF S.E.N.C.R.L. / LLP, 100, 12)
# 7073            (BCF S.E.N.C.R.L. / LLP, 100, 12)
# 7074            (BCF S.E.N.C.R.L. / LLP, 100, 12)
#                           ...
# 7513    (GREENBERG TRAURIG, LLP(BOSTON), 100, 65)
# 7514    (GREENBERG TRAURIG, LLP(BOSTON), 100, 65)
# 7515    (GREENBERG TRAURIG, LLP(BOSTON), 100, 65)
# Name: 委托人, Length: 444, dtype: object

# %%
scores = [x[1] for x in bestMatches]
results = [x[0] for x in bestMatches]
indices = [x[2] for x in bestMatches]

# %%
df = pd.DataFrame({'Original': cases_for_lookup['委托人'],
                   'Score': scores,
                   'Result': results, 
                  "ClientIndex": indices})
df
# Out:
#                             Original  Score                          Result  \
# 7072          BCF S.E.N.C.R.L. / LLP    100          BCF S.E.N.C.R.L. / LLP
# 7073          BCF S.E.N.C.R.L. / LLP    100          BCF S.E.N.C.R.L. / LLP
# 7074          BCF S.E.N.C.R.L. / LLP    100          BCF S.E.N.C.R.L. / LLP
# ...                              ...    ...                             ...
# 7513  GREENBERG TRAURIG, LLP(BOSTON)    100  GREENBERG TRAURIG, LLP(BOSTON)
# 7514  GREENBERG TRAURIG, LLP(BOSTON)    100  GREENBERG TRAURIG, LLP(BOSTON)
# 7515  GREENBERG TRAURIG, LLP(BOSTON)    100  GREENBERG TRAURIG, LLP(BOSTON)
#
#       ClientIndex
# 7072           12
# 7073           12
# 7074           12
# ...           ...
# 7513           65
# 7514           65
# 7515           65
#
# [444 rows x 4 columns]

# %% [markdown]
# ##### compare original vs. result with matching score above or equal to 95

# %%
df[df.Score >= 95]['Original'].unique()
# Out:
# array(['BCF S.E.N.C.R.L. / LLP', 'OYEN WIGGS GREEN & MUTALA LLP',
#        'LADAS & PARRY LLP(NEW YORK)',
#        'HARMAN INTERNATIONAL INDUSTRIES, INCORPORATED', 'YOUNIQUE, LLC',
#        'ITT MANUFACTURING ENTERPRISES LLC', 'MCCARTER & ENGLISH, LLP',
#        'SUNSTEIN KANN MURPHY & TIMBERS LLP',
#        'WARNER NORCROSS & JUDD LLP ',
#        'WOODARD, EMHARDT, MORIARTY, MCNETT & HENRY LLP', 'BUCHALTER',
#        'OLSHAN FROME WOLOSKY LLP', 'DOWNS RACHLIN MARTIN PLLC',
#        'SMART & BIGGAR', 'KLARQUIST SPARKMAN, LLP', 'ZIFF DAVIS, LLC',
#        'MINERALS TECHNOLOGIES INC.', 'HAROLD W. ASHENMIL, Q.C.',
#        'ICON HEALTH & FITNESS, INC.', 'YOUNG LIVING ESSENTIAL OILS',
#        'FOX ROTHSCHILD LLP', 'FOLEY & LARDNER LLP (WASHINGTON)',
#        'DLA PIPER LLP (US)', 'PATTERSON & SHERIDAN, LLP(HOUSTON)',
#        'OSLER, HOSKIN & HARCOURT LLP',
#        'PATTERSON THUENTE CHRISTENSEN PEDERSEN, P.A.(MINNEAPOLIS)',
#        'FITZPATRICK, CELLA, HARPER & SCINTO',
#        'KNOBBE MARTENS OLSON & BEAR LLP', 'IPR LAW GROUP',
#        'GRUMBLES LAW PLLC', 'HANLEY, FLIGHT & ZIMMERMAN, LLC',
#        'SCHWEGMAN LUNDBERG & WOESSNER', 'UNIVERSAL MUSIC GROUP',
#        'VISA INTERNATIONAL SERVICE ASSOCIATION',
#        'WOLF, GREENFIELD & SACKS, P.C.', 'WALKER STEVENS CANNOM YANG LLP',
#        'THE LAW FIRM OF BRIAN HARRISON ', 'IGLOO PRODUCTS CORP.',
#        'LATHAM & WATKINS LLP', 'PATTERSON & SHERIDAN, LLP(NEW YORK)',
#        'HERSCHEL SUPPLY COMPANY LTD.', 'EMERGECOUNSEL',
#        'SPECIALIZED BICYCLE COMPONENTS,INC.', 'IPHORGAN LTD',
#        'LADAS & PARRY LLP',
#        'LAPOINTE ROSENSTEIN MARCHAND MELAN?ON, L.L.P.',
#        'HARNESS, DICKEY & PIERCE, P.L.C.', 'TROUTMAN SANDERS LLP',
#        'RatnerPrestia', 'STINSON LEONARD STREET LLP',
#        'NELSON MULLINS RILEY & SCARBOROUGH LLP（CHARLOTTE）',
#        'BLANK ROME LLP', 'BANNER & WITCOFF, LTD.',
#        'PEARSON, BUTLER & CARSON PLLC', 'VELODYNE LIDAR, INC.',
#        'WOLF, GREENFIELD & SACKS, P.C. ', 'SHERIDAN ROSS PC',
#        'BOYLE FREDRICKSON S.C.', 'GREENBERG TRAURIG, LLP(BOSTON)'],
#       dtype=object)

# %%
df[df.Score >= 95]['Result'].unique()
# Out:
# array(['BCF S.E.N.C.R.L. / LLP', 'OYEN WIGGS GREEN & MUTALA LLP',
#        'LADAS & PARRY LLP(NEW YORK)',
#        'HARMAN INTERNATIONAL INDUSTRIES, INCORPORATED', 'YOUNIQUE, LLC',
#        'ITT MANUFACTURING ENTERPRISES LLC', 'MCCARTER & ENGLISH, LLP',
#        'SUNSTEIN KANN MURPHY & TIMBERS LLP', 'WARNER NORCROSS & JUDD LLP',
#        'WOODARD, EMHARDT, MORIARTY, MCNETT & HENRY LLP', 'BUCHALTER',
#        'OLSHAN FROME WOLOSKY LLP', 'DOWNS RACHLIN MARTIN PLLC',
#        'SMART & BIGGAR', 'KLARQUIST SPARKMAN, LLP', 'ZIFF DAVIS, LLC',
#        'MINERALS TECHNOLOGIES INC.', 'HAROLD W. ASHENMIL, Q.C.',
#        'ICON HEALTH & FITNESS, INC.', 'YOUNG LIVING ESSENTIAL OILS',
#        'FOX ROTHSCHILD LLP', 'FOLEY & LARDNER LLP (WASHINGTON)',
#        'DLA PIPER LLP (US)', 'PATTERSON & SHERIDAN, LLP(HOUSTON)',
#        'OSLER, HOSKIN & HARCOURT LLP',
#        'PATTERSON THUENTE PEDERSEN, P.A. (MINNEAPOLIS)',
#        'FITZPATRICK, CELLA, HARPER & SCINTO',
#        'KNOBBE MARTENS OLSON & BEAR LLP', 'IPR LAW GROUP',
#        'GRUMBLES LAW PLLC', 'HANLEY, FLIGHT & ZIMMERMAN, LLC',
#        'SCHWEGMAN LUNDBERG & WOESSNER', 'UNIVERSAL MUSIC GROUP',
#        'VISA INTERNATIONAL SERVICE ASSOCIATION',
#        'WOLF, GREENFIELD & SACKS, P.C.', 'WALKER STEVENS CANNOM YANG LLP',
#        'THE LAW FIRM OF BRIAN HARRISON ', 'IGLOO PRODUCTS CORP.',
#        'LATHAM & WATKINS LLP', 'PATTERSON & SHERIDAN, LLP(NEW YORK)',
#        'HERSCHEL SUPPLY COMPANY LTD.', 'EMERGECOUNSEL',
#        'SPECIALIZED BICYCLE COMPONENTS,INC.', 'IPHORGAN LTD',
#        'LADAS & PARRY LLP',
#        'LAPOINTE ROSENSTEIN MARCHAND MELANÇON, L.L.P.',
#        'HARNESS, DICKEY & PIERCE, P.L.C.', 'TROUTMAN SANDERS LLP',
#        'RatnerPrestia', 'STINSON LEONARD STREET LLP',
#        'NELSON MULLINS RILEY & SCARBOROUGH LLP (CHARLOTTE）',
#        'BLANK ROME LLP', 'BANNER & WITCOFF, LTD.',
#        'PEARSON, BUTLER & CARSON PLLC', 'VELODYNE LIDAR, INC.',
#        'SHERIDAN ROSS PC', 'BOYLE FREDRICKSON S.C.',
#        'GREENBERG TRAURIG, LLP(BOSTON)'], dtype=object)

# %%
# export result >= 95 to excel for review
notLowerThan_95 = df[df.Score >= 95]
notLowerThan_95.to_excel('notLowerThan_95.xlsx')

# %% [markdown]
# ##### compare original vs. result with matching score lower than 95

# %%
# export result < 95 to excel for review and add client (final.xlsx - 'clients' sheet), 
# once added, rerun the above cells until all client matches found
lowerThan_95 = df[df.Score < 95]
lowerThan_95.to_excel('lowerThan_95.xlsx')

# %% [markdown]
# - check lowerThan_95.xlsx file, if the client not in clients file yet, add it to `clients.xlsx`.
# - rerun the code to load in the updated clients file and do the matching again
# - when no more record in lowerThan_95.xlsx file, check notLowerThan_95.xlsx file, make sure the matching results are correct
# - go on into the following seesions to update case records.

# %% [markdown]
# #### Fill in 委托人性质 in cases dataframe

# %%
cases_rows_toUpdate = cases_for_lookup.index
cases_rows_toUpdate
# Out:
# Int64Index([7072, 7073, 7074, 7075, 7076, 7077, 7078, 7079, 7080, 7081,
#             ...
#             7506, 7507, 7508, 7509, 7510, 7511, 7512, 7513, 7514, 7515],
#            dtype='int64', length=444)

# %%
cases.loc[cases_rows_toUpdate, '委托人性质']
# Out:
# 7072    NaN
# 7073    NaN
# 7074    NaN
#        ...
# 7513    NaN
# 7514    NaN
# 7515    NaN
# Name: 委托人性质, Length: 444, dtype: object

# %% [markdown]
# #### Update 委托人性质 in cases

# %%
updateValues委托人性质 = df.merge(clients, left_on="ClientIndex", right_index = True)['委托人性质'].tolist()
updateValues委托人性质
# Out:
# ['合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '企业',
#  '合作所',
#  '合作所',
#  '合作所',
#  '企业',
#  '合作所',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '企业',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '企业',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所',
#  '合作所']

# %%
cases.loc[cases_rows_toUpdate, '委托人性质'] = updateValues委托人性质

# %%
cases.loc[cases_rows_toUpdate, '委托人性质']
# Out:
# 7072    合作所
# 7073    合作所
# 7074    合作所
#        ...
# 7513    合作所
# 7514    合作所
# 7515    合作所
# Name: 委托人性质, Length: 444, dtype: object

# %%
# verify if all cases have 委托人性质 filled in
cases.loc[cases.委托人性质.isna()]
# Out:
# Empty DataFrame
# Columns: [委托人, 委托人国别, 本所案号, 案件类型, 申请人, 申请人国别, 商标名称, 类别, 商标号, 立案日, 委托人性质, Year, Month]
# Index: []

# %% [markdown]
# #### Update 委托人 in cases

# %%
cases.loc[cases_rows_toUpdate, '委托人'] = clients.iloc[df['ClientIndex']]['委托人'].tolist()

# %% [markdown]
# ### Save updated case file to excel

# %%
# export the updated cases to final case file.
cases.to_excel('final.xlsx', header = True, index=False, encoding='utf-8')
